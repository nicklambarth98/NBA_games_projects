# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/nba-games/players.csv
# /kaggle/input/nba-games/teams.csv
# /kaggle/input/nba-games/ranking.csv
# /kaggle/input/nba-games/games_details.csv
# /kaggle/input/nba-games/games.csv

# %% [markdown]
# LIST OF TO DOs:
# 1. Basic EDA on each dataset.
# 2. Merge some datasets and plot things.
#     Plot average points per team home and away
#     Plot wins vs shot %

# %% [markdown]
# # Importing packages.
#
# For storage and manipulation of data we use pandas and numpy. For visualisations I am experimenting with plotly.

# %%
import pandas as pd
import numpy as np 
import plotly.express as px
from IPython.display import display

# %% [markdown]
# # Data Analysis
#
# Firsly we'll load the data into dataframes and check it all has converted correctly.
#
# Secondly we will plot the distribution of some interesting columns and relationships for each dataset. This will require some merging of datasets.

# %% [markdown]
# #### Games

# %%
games = pd.read_csv('/kaggle/input/nba-games/games.csv')

# %%
games.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2022-12-22  22200477            Final    1610612740       1610612759
# 1    2022-12-22  22200478            Final    1610612762       1610612764
# 2    2022-12-21  22200466            Final    1610612739       1610612749
# 3    2022-12-21  22200467            Final    1610612755       1610612765
# 4    2022-12-21  22200468            Final    1610612737       1610612741
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  AST_home  \
# 0    2022    1610612740     126.0        0.484        0.926  ...      25.0
# 1    2022    1610612762     120.0        0.488        0.952  ...      16.0
# 2    2022    1610612739     114.0        0.482        0.786  ...      22.0
# 3    2022    1610612755     113.0        0.441        0.909  ...      27.0
# 4    2022    1610612737     108.0        0.429        1.000  ...      22.0
#
#    REB_home  TEAM_ID_away  PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away  \
# 0      46.0    1610612759     117.0        0.478        0.815         0.321
# 1      40.0    1610612764     112.0        0.561        0.765         0.333
# 2      37.0    1610612749     106.0        0.470        0.682         0.433
# 3      49.0    1610612765      93.0        0.392        0.735         0.261
# 4      47.0    1610612741     110.0        0.500        0.773         0.292
#
#    AST_away  REB_away  HOME_TEAM_WINS
# 0      23.0      44.0               1
# 1      20.0      37.0               1
# 2      20.0      46.0               1
# 3      15.0      46.0               1
# 4      20.0      47.0               0
#
# [5 rows x 21 columns]

# %%
games.shape
# Out:
# (26651, 21)

# %%
games.columns
# Out:
# Index(['GAME_DATE_EST', 'GAME_ID', 'GAME_STATUS_TEXT', 'HOME_TEAM_ID',
#        'VISITOR_TEAM_ID', 'SEASON', 'TEAM_ID_home', 'PTS_home', 'FG_PCT_home',
#        'FT_PCT_home', 'FG3_PCT_home', 'AST_home', 'REB_home', 'TEAM_ID_away',
#        'PTS_away', 'FG_PCT_away', 'FT_PCT_away', 'FG3_PCT_away', 'AST_away',
#        'REB_away', 'HOME_TEAM_WINS'],
#       dtype='object')

# %% [markdown]
# Checking for any NaN values in the dataset

# %%
games.isna().sum()
# Out:
# GAME_DATE_EST        0
# GAME_ID              0
# GAME_STATUS_TEXT     0
# HOME_TEAM_ID         0
# VISITOR_TEAM_ID      0
# SEASON               0
# TEAM_ID_home         0
# PTS_home            99
# FG_PCT_home         99
# FT_PCT_home         99
# FG3_PCT_home        99
# AST_home            99
# REB_home            99
# TEAM_ID_away         0
# PTS_away            99
# FG_PCT_away         99
# FT_PCT_away         99
# FG3_PCT_away        99
# AST_away            99
# REB_away            99
# HOME_TEAM_WINS       0
# dtype: int64

# %% [markdown]
# The na values will have to be dealt with.
#
# There are three primary ways to deal with this. Each NA value could be made zero, in this case that would not be the best option due to the way this would skew the data given that the columns with NA are pts, shot %, assists and rebounds.
#
# The other two ways are making the value the mean/median/mode of the respective column or deleting the column all together. Deleting the columns would not necessarily be bad given that there are only 99/26651 with NA data. This would mean we are dropping 0.37% of the data.
#
# Using the mean of the columns is also not necessarily bad but can be refined. One way to do this would be to, for example, find, for each specific home team, the average pts scored.

# %% [markdown]
# From this table it appears that all NaN values are in the same rows. To double check, we'll check the sums of NaN values again.

# %% [markdown]
# Finding the team names for which the data is missing.

# %%
teams = pd.read_csv('/kaggle/input/nba-games/teams.csv')
teams.shape
# Out:
# (30, 14)

# %%
teams.isna().sum()
# Out:
# LEAGUE_ID             0
# TEAM_ID               0
# MIN_YEAR              0
# MAX_YEAR              0
# ABBREVIATION          0
# NICKNAME              0
# YEARFOUNDED           0
# CITY                  0
# ARENA                 0
# ARENACAPACITY         4
# OWNER                 0
# GENERALMANAGER        0
# HEADCOACH             0
# DLEAGUEAFFILIATION    0
# dtype: int64

# %% [markdown]
# We'll rename the "TEAM_ID" column in teams to "HOME_TEAM_ID" so that the dataframes can be merged

# %%
teams = teams.rename(columns = {"TEAM_ID":"HOME_TEAM_ID"})
teams.columns
# Out:
# Index(['LEAGUE_ID', 'HOME_TEAM_ID', 'MIN_YEAR', 'MAX_YEAR', 'ABBREVIATION',
#        'NICKNAME', 'YEARFOUNDED', 'CITY', 'ARENA', 'ARENACAPACITY', 'OWNER',
#        'GENERALMANAGER', 'HEADCOACH', 'DLEAGUEAFFILIATION'],
#       dtype='object')

# %%
games_teams_merged = pd.merge(games, teams,on="HOME_TEAM_ID")
games_teams_merged.head()
# Out:
#   GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 0    2022-12-22  22200477            Final    1610612740       1610612759
# 1    2022-12-19  22200457            Final    1610612740       1610612749
# 2    2022-12-11  22200395            Final    1610612740       1610612756
# 3    2022-12-09  22200384            Final    1610612740       1610612756
# 4    2022-12-07  22200371            Final    1610612740       1610612765
#
#    SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  \
# 0    2022    1610612740     126.0        0.484        0.926  ...
# 1    2022    1610612740     119.0        0.424        0.708  ...
# 2    2022    1610612740     129.0        0.581        0.750  ...
# 3    2022    1610612740     128.0        0.511        0.800  ...
# 4    2022    1610612740     104.0        0.459        0.783  ...
#
#    ABBREVIATION  NICKNAME  YEARFOUNDED         CITY                 ARENA  \
# 0           NOP  Pelicans         2002  New Orleans  Smoothie King Center
# 1           NOP  Pelicans         2002  New Orleans  Smoothie King Center
# 2           NOP  Pelicans         2002  New Orleans  Smoothie King Center
# 3           NOP  Pelicans         2002  New Orleans  Smoothie King Center
# 4           NOP  Pelicans         2002  New Orleans  Smoothie King Center
#
#    ARENACAPACITY       OWNER  GENERALMANAGER     HEADCOACH  DLEAGUEAFFILIATION
# 0            NaN  Tom Benson  Trajan Langdon  Alvin Gentry        No Affiliate
# 1            NaN  Tom Benson  Trajan Langdon  Alvin Gentry        No Affiliate
# 2            NaN  Tom Benson  Trajan Langdon  Alvin Gentry        No Affiliate
# 3            NaN  Tom Benson  Trajan Langdon  Alvin Gentry        No Affiliate
# 4            NaN  Tom Benson  Trajan Langdon  Alvin Gentry        No Affiliate
#
# [5 rows x 34 columns]

# %%
df2 = games_teams_merged.loc[games_teams_merged.PTS_home.isna()]
display(df2)
# Out:
#       GAME_DATE_EST   GAME_ID GAME_STATUS_TEXT  HOME_TEAM_ID  VISITOR_TEAM_ID  \
# 614      2003-10-18  10300079            Final    1610612740       1610612764
# 615      2003-10-16  10300059            Final    1610612740       1610612741
# 1481     2003-10-17  10300065            Final    1610612762       1610612755
# 1482     2003-10-16  10300061            Final    1610612762       1610612753
# 1483     2003-10-14  10300052            Final    1610612762       1610612752
# ...             ...       ...              ...           ...              ...
# 25496    2003-10-14  10300053            Final    1610612757       1610612760
# 25497    2003-10-09  10300022            Final    1610612757       1610612758
# 26359    2003-10-19  10300084            Final    1610612744       1610612746
# 26360    2003-10-15  10300056            Final    1610612744       1610612760
# 26361    2003-10-11  10300037            Final    1610612744       1610612758
#
#        SEASON  TEAM_ID_home  PTS_home  FG_PCT_home  FT_PCT_home  ...  \
# 614      2003    1610612740       NaN          NaN          NaN  ...
# 615      2003    1610612740       NaN          NaN          NaN  ...
# 1481     2003    1610612762       NaN          NaN          NaN  ...
# 1482     2003    1610612762       NaN          NaN          NaN  ...
# 1483     2003    1610612762       NaN          NaN          NaN  ...
# ...       ...           ...       ...          ...          ...  ...
# 25496    2003    1610612757       NaN          NaN          NaN  ...
# 25497    2003    1610612757       NaN          NaN          NaN  ...
# 26359    2003    1610612744       NaN          NaN          NaN  ...
# 26360    2003    1610612744       NaN          NaN          NaN  ...
# 26361    2003    1610612744       NaN          NaN          NaN  ...
#
#        ABBREVIATION       NICKNAME  YEARFOUNDED          CITY  \
# 614             NOP       Pelicans         2002   New Orleans
# 615             NOP       Pelicans         2002   New Orleans
# 1481            UTA           Jazz         1974          Utah
# 1482            UTA           Jazz         1974          Utah
# 1483            UTA           Jazz         1974          Utah
# ...             ...            ...          ...           ...
# 25496           POR  Trail Blazers         1970      Portland
# 25497           POR  Trail Blazers         1970      Portland
# 26359           GSW       Warriors         1946  Golden State
# 26360           GSW       Warriors         1946  Golden State
# 26361           GSW       Warriors         1946  Golden State
#
#                          ARENA  ARENACAPACITY        OWNER  GENERALMANAGER  \
# 614       Smoothie King Center            NaN   Tom Benson  Trajan Langdon
# 615       Smoothie King Center            NaN   Tom Benson  Trajan Langdon
# 1481   Vivint Smart Home Arena        20148.0  Greg Miller  Dennis Lindsey
# 1482   Vivint Smart Home Arena        20148.0  Greg Miller  Dennis Lindsey
# 1483   Vivint Smart Home Arena        20148.0  Greg Miller  Dennis Lindsey
# ...                        ...            ...          ...             ...
# 25496              Moda Center        19980.0   Paul Allen     Neil Olshey
# 25497              Moda Center        19980.0   Paul Allen     Neil Olshey
# 26359             Chase Center        19596.0    Joe Lacob       Bob Myers
# 26360             Chase Center        19596.0    Joe Lacob       Bob Myers
# 26361             Chase Center        19596.0    Joe Lacob       Bob Myers
#
#           HEADCOACH    DLEAGUEAFFILIATION
# 614    Alvin Gentry          No Affiliate
# 615    Alvin Gentry          No Affiliate
# 1481    Quin Snyder  Salt Lake City Stars
# 1482    Quin Snyder  Salt Lake City Stars
# 1483    Quin Snyder  Salt Lake City Stars
# ...             ...                   ...
# 25496  Terry Stotts          No Affiliate
# 25497  Terry Stotts          No Affiliate
# 26359    Steve Kerr   Santa Cruz Warriors
# 26360    Steve Kerr   Santa Cruz Warriors
# 26361    Steve Kerr   Santa Cruz Warriors
#
# [99 rows x 34 columns]

# %%
df2.isna().sum()
# Out:
# GAME_DATE_EST          0
# GAME_ID                0
# GAME_STATUS_TEXT       0
# HOME_TEAM_ID           0
# VISITOR_TEAM_ID        0
# SEASON                 0
# TEAM_ID_home           0
# PTS_home              99
# FG_PCT_home           99
# FT_PCT_home           99
# FG3_PCT_home          99
# AST_home              99
# REB_home              99
# TEAM_ID_away           0
# PTS_away              99
# FG_PCT_away           99
# FT_PCT_away           99
# FG3_PCT_away          99
# AST_away              99
# REB_away              99
# HOME_TEAM_WINS         0
# LEAGUE_ID              0
# MIN_YEAR               0
# MAX_YEAR               0
# ABBREVIATION           0
# NICKNAME               0
# YEARFOUNDED            0
# CITY                   0
# ARENA                  0
# ARENACAPACITY         11
# OWNER                  0
# GENERALMANAGER         0
# HEADCOACH              0
# DLEAGUEAFFILIATION     0
# dtype: int64

# %%
#unique_ids = df2["HOME_TEAM_ID"].unique()
_ = df2["ABBREVIATION"].value_counts()
print(_)
# Out:
# LAL    8
# SAS    5
# DET    5
# LAC    5
# MIN    4
# UTA    4
# CHI    4
# HOU    4
# NYK    4
# BKN    4
# ORL    4
# POR    4
# TOR    3
# MIL    3
# DAL    3
# MEM    3
# MIA    3
# GSW    3
# IND    3
# SAC    3
# BOS    3
# PHI    3
# DEN    2
# PHX    2
# OKC    2
# ATL    2
# WAS    2
# CLE    2
# NOP    2
# Name: ABBREVIATION, dtype: int64

# %% [markdown]
# There are 29 of 30 teams have missing values, the top being the lakers with 8. The only team without missing values is the Charlotte Hornets.
#
# Given the low numbers of missing values per team, the 99 rows with NaN values will be dropped.

# %%
games_clean = games_teams_merged.dropna(axis=0)
games_clean.isna().sum()
# Out:
# GAME_DATE_EST         0
# GAME_ID               0
# GAME_STATUS_TEXT      0
# HOME_TEAM_ID          0
# VISITOR_TEAM_ID       0
# SEASON                0
# TEAM_ID_home          0
# PTS_home              0
# FG_PCT_home           0
# FT_PCT_home           0
# FG3_PCT_home          0
# AST_home              0
# REB_home              0
# TEAM_ID_away          0
# PTS_away              0
# FG_PCT_away           0
# FT_PCT_away           0
# FG3_PCT_away          0
# AST_away              0
# REB_away              0
# HOME_TEAM_WINS        0
# LEAGUE_ID             0
# MIN_YEAR              0
# MAX_YEAR              0
# ABBREVIATION          0
# NICKNAME              0
# YEARFOUNDED           0
# CITY                  0
# ARENA                 0
# ARENACAPACITY         0
# OWNER                 0
# GENERALMANAGER        0
# HEADCOACH             0
# DLEAGUEAFFILIATION    0
# dtype: int64

# %% [markdown]
# Getting the average of home and away scores, all fg%s, ast and reb for each team

# %%
unique_t = games_clean.ABBREVIATION.unique()
cols=["PTS_home","FG_PCT_home","FT_PCT_home","FG3_PCT_home","AST_home", "REB_home",
         "PTS_away","FG_PCT_away","FT_PCT_away","FG3_PCT_away","AST_away", "REB_away"]
cols2= cols.insert(0,"ABBREVIATION")
team_means = pd.DataFrame(columns = cols2)

i=0
for t in unique_t:
    t_games = games_clean.loc[games_clean["ABBREVIATION"] == t]
    means = t_games[cols].mean().to_frame().transpose()
    means["ABBREVIATION"] = t
    team_means = team_means.append(means)
    i+=1
    #HOME_TEAM_ID

display(team_means)
# Out:
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
# /tmp/ipykernel_20/830926374.py:10: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   means = t_games[cols].mean().to_frame().transpose()
# /tmp/ipykernel_20/830926374.py:12: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   team_means = team_means.append(means)
#      PTS_home  FG_PCT_home  FT_PCT_home  FG3_PCT_home   AST_home   REB_home  \
# 0  103.385057     0.470034     0.752774      0.360905  22.556322  43.637931
# 0  101.893362     0.457421     0.745542      0.358482  22.894450  43.758433
# 0  102.835414     0.459980     0.767011      0.351469  23.774120  42.632236
# 0  102.643083     0.463992     0.777646      0.356264  23.697994  42.473073
# 0  102.007177     0.451971     0.765228      0.350065  20.477273  43.279904
# 0  104.729911     0.452238     0.748867      0.350980  22.094866  44.056920
# 0  102.463820     0.453962     0.766892      0.342883  22.976275  43.287070
# 0  105.258137     0.463669     0.774749      0.356364  21.534231  44.122334
# 0  105.307049     0.464099     0.765358      0.360559  22.033453  42.364397
# 0  103.840757     0.465658     0.750304      0.349842  23.758352  43.145880
# 0   99.763920     0.452146     0.737775      0.344522  22.537862  43.222717
# 0  102.184100     0.472661     0.747487      0.356917  21.025105  41.709205
# 0  108.634902     0.470599     0.752627      0.352187  25.556831  44.672790
# 0  102.376126     0.453713     0.767537      0.356480  22.006757  44.139640
# 0  104.147523     0.459671     0.785481      0.359061  22.176802  42.373874
# 0  104.457856     0.460431     0.742245      0.341751  23.659729  44.441207
# 0  104.053362     0.478890     0.758007      0.387371  23.993597  43.324440
# 0  104.085227     0.461247     0.755603      0.364081  23.639773  43.698864
# 0  100.620301     0.444371     0.748851      0.347204  22.602757  42.719298
# 0  100.585475     0.446363     0.764842      0.358065  23.188827  45.052514
# 0  104.956858     0.463106     0.783205      0.362954  22.191372  43.415929
# 0  101.575654     0.456776     0.755509      0.344246  21.569966  43.225256
# 0  101.300459     0.458409     0.744530      0.353010  21.317661  43.442661
# 0  104.040047     0.459750     0.757449      0.355603  22.563015  42.994111
# 0  103.867359     0.459435     0.777657      0.364968  21.824683  43.319493
# 0  109.537611     0.474590     0.767539      0.374571  26.172566  44.150442
#
#      PTS_away  FG_PCT_away  FT_PCT_away  FG3_PCT_away   AST_away   REB_away  \
# 0   98.005747     0.444785     0.761690      0.354489  18.758621  39.359770
# 0   99.287269     0.449975     0.756177      0.356473  22.767138  40.848749
# 0  101.295119     0.453045     0.761622      0.350910  22.363224  42.492622
# 0   98.100317     0.440027     0.755522      0.333277  20.776135  41.652587
# 0  102.391148     0.456697     0.757018      0.355895  20.476077  42.360048
# 0  100.308036     0.445132     0.747233      0.342571  21.333705  42.712054
# 0  102.526690     0.457005     0.758580      0.354918  22.381969  42.398577
# 0  101.932660     0.450149     0.761888      0.353254  21.176207  41.132435
# 0  105.203106     0.463256     0.767470      0.357591  21.989247  42.602151
# 0  100.863029     0.446419     0.754406      0.340589  22.604677  42.233853
# 0   97.443207     0.450668     0.758071      0.336225  21.636971  41.384187
# 0   97.641213     0.443626     0.760073      0.348046  19.314854  40.563808
# 0  103.125144     0.451633     0.749287      0.351118  23.304248  41.917336
# 0   98.400901     0.438065     0.757511      0.342848  19.863739  42.950450
# 0  100.619369     0.452209     0.762785      0.358122  21.816441  41.797297
# 0  101.702393     0.445767     0.750299      0.339657  23.174818  42.854318
# 0   96.706510     0.445297     0.757457      0.352249  19.849520  41.105656
# 0  101.562500     0.450475     0.767703      0.356903  22.643182  42.295455
# 0  100.740602     0.451909     0.754940      0.345357  22.200501  43.068922
# 0   98.639106     0.441517     0.753496      0.342149  21.562011  42.545251
# 0  100.132743     0.451597     0.756585      0.347781  20.298673  42.970133
# 0   98.911263     0.446858     0.762848      0.350900  20.707622  41.890785
# 0  100.293578     0.449092     0.758232      0.353960  21.058486  41.955275
# 0  102.871614     0.457627     0.766941      0.354527  22.348645  42.605418
# 0  101.092272     0.455621     0.765191      0.355746  21.242215  41.397924
# 0  103.564159     0.444616     0.759354      0.346169  23.109513  44.046460
#
#   ABBREVIATION
# 0          UTA
# 0          CLE
# 0          ATL
# 0          BOS
# 0          NYK
# 0          HOU
# 0          MIN
# 0          OKC
# 0          SAC
# 0          LAC
# 0          DET
# 0          MIA
# 0          DEN
# 0          IND
# 0          TOR
# 0          LAL
# 0          SAS
# 0          MIL
# 0          CHA
# 0          CHI
# 0          DAL
# 0          MEM
# 0          ORL
# 0          WAS
# 0          POR
# 0          GSW

# %% [markdown]
# Visualising which team scores and concedes the most points on average when home.

# %%
fig = px.bar(team_means,x='ABBREVIATION',y="PTS_home")
fig.show()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# <div>                            <div id="1e4d837f-a9dc-472f-9e56-7581b4050686" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1e4d837f-a9dc-472f-9e56-7581b4050686")) {                    Plotly.newPlot(                        "1e4d837f-a9dc-472f-9e56-7581b4050686",                        [{"alignmentgroup":"True","hovertemplate":"ABBREVIATION=%{x}<br>PTS_home=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["UTA","CLE","ATL","BOS","NYK","HOU","MIN","OKC","SAC","LAC","DET","MIA","DEN","IND","TOR","LAL","SAS","MIL","CHA","CHI","DAL","MEM","ORL","WAS","POR","GSW"],"xaxis":"x","y":[103.38505747126437,101.89336235038085,102.83541430192963,102.64308342133052,102.00717703349282,104.72991071428571,102.4638196915777,105.2581369248036,105.30704898446834,103.84075723830735,99.76391982182628,102.18410041841004,108.63490241102181,102.37612612612612,104.14752252252252,104.45785639958376,104.05336179295624,104.08522727272727,100.6203007518797,100.5854748603352,104.95685840707965,101.57565415244596,101.30045871559633,104.04004711425206,103.86735870818916,109.53761061946902],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{ ...

# %%
fig = px.bar(team_means,x='ABBREVIATION',y='PTS_away')
fig.show()
# Out:
# <div>                            <div id="26eac84a-ca1f-474e-83bd-0e44752ea23f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("26eac84a-ca1f-474e-83bd-0e44752ea23f")) {                    Plotly.newPlot(                        "26eac84a-ca1f-474e-83bd-0e44752ea23f",                        [{"alignmentgroup":"True","hovertemplate":"ABBREVIATION=%{x}<br>PTS_away=%{y}<extra></extra>","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["UTA","CLE","ATL","BOS","NYK","HOU","MIN","OKC","SAC","LAC","DET","MIA","DEN","IND","TOR","LAL","SAS","MIL","CHA","CHI","DAL","MEM","ORL","WAS","POR","GSW"],"xaxis":"x","y":[98.00574712643679,99.2872687704026,101.29511918274687,98.10031678986273,102.39114832535886,100.30803571428571,102.52669039145907,101.93265993265993,105.20310633213859,100.8630289532294,97.44320712694878,97.64121338912133,103.12514351320321,98.40090090090091,100.61936936936937,101.70239334027055,96.70651013874067,101.5625,100.7406015037594,98.6391061452514,100.13274336283186,98.91126279863481,100.29357798165138,102.8716136631331,101.09227220299884,103.5641592920354],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fill ...

# %% [markdown]
# Are points scored consistent accross the year?
#
# Will also need to repeat the above work to get the averages for when the team is AWAY.

# %% [markdown]
# #### Games Details

# %%
games_details = pd.read_csv('/kaggle/input/nba-games/games_details.csv')
# Out:
# /tmp/ipykernel_20/2644165350.py:1: DtypeWarning:
#
# Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.

# %% [markdown]
# #### Players

# %%
players = pd.read_csv('/kaggle/input/nba-games/players.csv')

# %% [markdown]
# #### Ranking

# %%
ranking = pd.read_csv('/kaggle/input/nba-games/ranking.csv')

# %% [markdown]
# #### Teams
